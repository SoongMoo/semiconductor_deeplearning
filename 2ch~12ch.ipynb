# %%
x = np.array([2, 4, 6, 8])     # 공부 시간 numpy배열 만듦
y = np.array([81, 93, 91, 97])
model = Sequential()
model.add(Dense(1, input_dim=1, activation='linear'))
model.compile(optimizer='adam', loss='mse')
model.fit(x, y, epochs=500, verbose=0)

# %%
x = np.array([[2, 0], [4, 4], [6, 2], [8, 3]])
y = np.array([81, 93, 91, 97])
model = Sequential()
model.add(Dense(1, input_dim=2, activation='linear'))
model.compile(optimizer='adam', loss='mse')
model.fit(x, y, epochs=500, verbose=0)

# %%
x = np.array([2, 4, 6, 8, 10, 12, 14]) # 공부 시간
y = np.array([0, 0, 0, 1, 1, 1, 1]) # 0은 불합격 1은 합격
model = Sequential() # 모델 생성
model.add(Dense(1, input_dim=1, activation='sigmoid'))
model.compile(optimizer='adam' ,loss='binary_crossentropy')

# %%
Data_set = np.loadtxt("./data/ThoraricSurgery3.csv", delimiter=",")
X = Data_set[:,0:16]
y = Data_set[:,16]
model = Sequential()
model.add(Dense(30, input_dim=16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# %%
df = pd.read_csv('./data/iris3.csv') # 3개 출력
X = df.iloc[:,0:4]
y = df.iloc[:,4]  # 문자
# 원-핫 인코딩 처리를 합니다.
y = pd.get_dummies(y)
'''
        Iris-setosa  Iris-versicolor  Iris-virginica
0            1                0               0
1            0                1               0
2            0                0               1
'''
model = Sequential()
model.add(Dense(12,  input_dim=4, activation='relu'))
model.add(Dense(8,  activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-322933123.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('./data/iris3.csv') # 3개 출력
#
# NameError: name 'pd' is not defined
